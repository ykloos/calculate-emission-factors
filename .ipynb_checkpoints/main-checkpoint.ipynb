# %% [markdown]
# # Introduction

# %% [markdown]
# This Notebook is a step for step handbook for calculating the emission factors of conventional power plants in Germany.
#
# Only plants, that are mandated to submit generation data are included. This refers to plants with a total nominal electrical power of least 200 MW or single blocks with a nominal elctrical power of at least 100 MW.

# %% [markdown]
# ## Preparation of Python environment
#
# The following modules and their dependencies are required to run this notebook:
# * Pandas
# * Numpy

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from pandas import read_excel
import os

# %% [markdown]
# ## Download of input files and setup of folder structure

# %% [markdown]
# We need to download and prepare the data. We need the _blocks.xlsx_ data, which is a list of all powerplants in Germany.
#
# Also we need the Generation Data from the Smard Website, which can be downloaded here:
# https://www.smard.de/en/downloadcenter/download-power-plant-data/?downloadAttributes=%7B%22selectedPowerPlant%22:%22all%22,%22selectedContent%22:%22generation%22,%22from%22:1451602800000,%22to%22:1483225199999,%22selectedFileType%22:%22CSV%22%7D
# It needs to be downloaded for each year independently from year 2016 to 2021. Then each csv needs to be put into the _smard_ folder
#
# Then we also need the Verified emissions from 2021 which can be downloaded here https://climate.ec.europa.eu/eu-action/eu-emissions-trading-system-eu-ets/union-registry_en#documentation Access the link, go to section *Phase IV (2021-2030)* - *Reports* and download the file *Verified Emissions for 2021*. Delete the informational rows marked in yellow. Include the file into the */input/EC* folder.

# %%
# INITIAL SETUP

# data is currently provided for the years of 2016 to 2021
#years = [2016, 2017, 2018, 2019, 2020, 2021]
years = [2017]

# import main file for German powerplant data including EIC, ETS-ID, electrical and heat power, CHP
blocks = pd.read_excel('input/blocks.xlsx')
# output
blocks.head(10)
# Out:
#    ETS-ID               EIC    BNA-ID  \
# 0      19  11WD8SCHW5X---19  BNA0894c
# 1      19  11WD8SCHW5X---27  BNA0894d
# 2     662  11WD7LUDW2GGT11E  BNA0614b
# 3     662  11WD7LUDW2GGT12C  BNA0614b
# 4    1484  11WD7LUDW5GSDG1Q   BNA0615
# 5    1484  11WD7LUDW5GSDG2O   BNA0615
# 6     739  11WD8DRES5X----D   BNA0207
# 7     741  11WD2NOR20001055  BNA0969b
# 8     750  11WD2S1G2000097U  BNA0683c
# 9     750  11WD2S1G3000098K  BNA0683b
#
#                                             MaStR-Nr               Name BNA  \
# 0                                    SEE954086855965                   1MKA
# 1                                    SEE995943794058                   2MKA
# 2                                    SEE920494524915         GuD Mitte GT11
# 3                                    SEE914414538991         GuD Mitte GT12
# 4                                    SEE944122961347            GuD Süd GT1
# 5                                    SEE923421872301            GuD Süd GT2
# 6  SEE950477241393+SEE967194778880+SEE96825436577...         DT+GT1+GT2+GT3
# 7                                    SEE952372080091     SWM HKW Nord 2 T20
# 8                                    SEE901789931854  SWM HKW Sued GuD1 GT2
# 9                                    SEE985585573104  SWM HKW Sued GuD1 GT3
#
#            City                    Plant name Block name  CHP  \
# 0       Schwedt               IKS PCK Schwedt          1    1
# 1       Schwedt               IKS PCK Schwedt          2    1
# 2  Ludwigshafen                         Mitte       GT11    1
# 3  Ludwigshafen                         Mitte       GT12    1
# 4  Ludwigshafen                          Sued        GT1    1
# 5  Ludwigshafen                          Sued        GT2    1
# 6       Dresden  HKW Dresden Nossener Bruecke        NaN    1
# 7      Muenchen                          Nord      2-T20    1
# 8      Muenchen                          Sued        GT2    1
# 9      Muenchen                          Sued        GT3    1
#
#    Net electrical power [MW_el]  Heat power [MW_th]       Fuel  \
# 0                           117               106.0  crude oil
# 1                           117               106.0  crude oil
# 2                           206               270.0         NG
# 3                           206               270.0         NG
# 4                           178               217.0         NG
# 5                           167               203.0         NG
# 6                           260               455.0         NG
# 7                           333               550.0  hard coal
# 8                           108                92.0         NG
# 9                           108                92.0         NG
#
#    Fuel emission factor [t/MWh_th] ETS-ID Correct  Old ETS-ID Notes  \
# 0                           0.2639            yes         NaN   NaN
# 1                           0.2639            yes         NaN   NaN
# 2                           0.2010            yes         NaN   NaN
# 3                           0.2010            yes         NaN   NaN
# 4                           0.2010             no       662.0   NaN
# 5                           0.2010             no       662.0   NaN
# 6                           0.2010            yes         NaN   NaN
# 7                           0.3368            yes         NaN   NaN
# 8                           0.2010            yes         NaN   NaN
# 9                           0.2010            yes         NaN   NaN
#
#   Stilllegung                               filename
# 0         NaN                        IKS_PCK_Schwedt
# 1         NaN                        IKS_PCK_Schwedt
# 2         NaN      Kraftwerk_BASF_Ludwigshafen_Mitte
# 3         NaN      Kraftwerk_BASF_Ludwigshafen_Mitte
# 4         NaN        Kraftwerk_BASF_Ludwigshafen_S_d
# 5         NaN        Kraftwerk_BASF_Ludwigshafen_S_d
# 6         NaN  Heizkraftwerk_Dresden-Nossener_Br_cke
# 7         NaN                         M_nchen_Nord_2
# 8         NaN         Heizkraftwerk_M_nchen_S_d_GUD1
# 9         NaN         Heizkraftwerk_M_nchen_S_d_GUD1

# %% [markdown]
# ### Prepare the smard data
# As in the smard data we have a file for each powerplant and year we generate a Dataframe which maps
# the files to the correct plant name. This plant name is also present in the column _filename_ in the _blocks.xlsx_ data

# %%
# Folder which contains all smard data files
smard_folder = "./input/smard"
files = os.listdir(smard_folder)

# Initialize columns for DataFrame, in which we save the year, the plant name and the filename
years = []
plant_names = []
filenames = []

# Loop through all filenames, except the first, as this is the .gitignore
for filename in files:
    # Split the filename on underscore, to get each information saved in the filename
    filename_array = filename.split("_")
    
    # Check if file is csv file
    if filename_array[-1].split(".")[1] != "csv":
        continue
    # Save filename in the designated array
    filenames.append(filename)
    
    # Get year and plant name and save them in the arrays
    years.append(filename_array[-3][:4])
    plant_names.append("_".join(filename_array[:-4]))

# Convert everything to a DataFrame
smard_files_df = pd.DataFrame({"year":years, "plant name":plant_names, "filename":filenames})
smard_files_df.head(20)
# Out:
#     year                        plant name  \
# 0   2017                    Abwinden-Asten
# 1   2017                       Ahrensfelde
# 2   2017                        Altenw_rth
# 3   2017                    Amrumbank_West
# 4   2017                           Aschach
# 5   2017                         Bergkamen
# 6   2017                          Bleiloch
# 7   2017                           Boxberg
# 8   2017    Braunkohlekraftwerk_Lippendorf
# 9   2017                          Brokdorf
# 10  2017                       Brunsb_ttel
# 11  2017                     Burghausen_GT
# 12  2017                         Buschhaus
# 13  2017                    Charlottenburg
# 14  2017     Chemiepark_Marl_Kraftwerk_III
# 15  2017      Chemiepark_Marl_Kraftwerk_II
# 16  2017       Chemiepark_Marl_Kraftwerk_I
# 17  2017       Cuno_Heizkraftwerk_Herdecke
# 18  2017  Dampfkraftwerk_Marbach_am_Neckar
# 19  2017                           Datteln
#
#                                              filename
# 0   Abwinden-Asten_201701010000_201712312359_Hour_...
# 1    Ahrensfelde_201701010000_201712312359_Hour_2.csv
# 2     Altenw_rth_201701010000_201712312359_Hour_3.csv
# 3   Amrumbank_West_201701010000_201712312359_Hour_...
# 4        Aschach_201701010000_201712312359_Hour_5.csv
# 5      Bergkamen_201701010000_201712312359_Hour_6.csv
# 6       Bleiloch_201701010000_201712312359_Hour_7.csv
# 7        Boxberg_201701010000_201712312359_Hour_8.csv
# 8   Braunkohlekraftwerk_Lippendorf_201701010000_20...
# 9      Brokdorf_201701010000_201712312359_Hour_10.csv
# 10  Brunsb_ttel_201701010000_201712312359_Hour_11.csv
# 11  Burghausen_GT_201701010000_201712312359_Hour_1...
# 12    Buschhaus_201701010000_201712312359_Hour_13.csv
# 13  Charlottenburg_201701010000_201712312359_Hour_...
# 14  Chemiepark_Marl_Kraftwerk_III_201701010000_201...
# 15  Chemiepark_Marl_Kraftwerk_II_201701010000_2017...
# 16  Chemiepark_Marl_Kraftwerk_I_201701010000_20171...
# 17  Cuno_Heizkraftwerk_Herdecke_201701010000_20171...
# 18  Dampfkraftwerk_Marbach_am_Neckar_201701010000_...
# 19      Datteln_201701010000_201712312359_Hour_20.csv

# %% [markdown]
# First we get all unique IDs for ETS and EIC IDs out of the blocks.xlsx list

# %%
# GENERATION OF EIC AND ETS-ID LISTS

# list of all powerplant block EIC codes
eic_list = blocks['EIC'].unique()

# list of all powerplant location ETS-ID codes
ets_list = blocks['ETS-ID'].unique()

# %% [markdown]
# Now we need to import the generation data from the smard csv files. To do that we loop over the EIC IDs in the blocks list.
# Then for each unit we sum up the yearly data and save it to the DataFrame _smard_generation_data_df_. So in this DataFrame we have
# for each EIC and year an entry with the yearly generation data.

# %%
# Importing the generation Data from the smard csv files
smard_generation_data = []

# Iterate over the files of smard data
for row in smard_files_df.values:
    plant_name = row[1]
    year = row[0]
    filename = row[2]
    gen_units = blocks[blocks["filename"] == plant_name]  
    
    # Check if a matching eic id (or multiple) exist for that file
    if len(gen_units) == 0:
        continue
    # Load the smard data
    try:
        smard_data_df = read_csv(smard_folder + "/" + filename, delimiter = ";")

        # Rename the columns containing the Generatio data, so we can get the correct data for each block
        smard_data_df = smard_data_df.rename(columns={"Start": "start", "Date": "date", "End":"end"})
        smard_data_df = smard_data_df.rename(lambda x: "_".join(x.split(" ")[1:-3]) if "Generation_DE" in x else x, axis="columns")
        if len(gen_units) == 1:
            smard_data_df[:,3] = pd.to_numeric(smard_data_df[:,3], errors="coerce")
            gen_data_unit += smard_data_df[:,3].sum()
            entry = {"EIC-ID": eic_id, "Generation Year":gen_data_unit, "Year":year,
                        "Plant Name":plant_name}
            smard_generation_data.append(entry)
        else:
            for gen_unit in gen_units.values:
                block_name = gen_unit[7]                   
                block_cols = [col for col in smard_data_df.columns if block_name in col]
                eic_id = gen_unit[1]
                gen_data_unit = 0
                if len(block_cols) > 0:
                    for col in block_cols: 
                        smard_data_df[col] = pd.to_numeric(smard_data_df[col], errors="coerce")
                        gen_data_unit += smard_data_df[col].sum()
                    entry = {"EIC-ID": eic_id, "Generation Year":gen_data_unit, "Year":year,
                            "Plant Name":plant_name}
                    smard_generation_data.append(entry)
                else:
                    print(f"Block name is {block_name}")
            
    except:
        print(f"Data in filename {filename} invalid")

smard_generation_data_df = pd.DataFrame(smard_generation_data)
smard_generation_data_df
# Out:
# Data in filename Bergkamen_201701010000_201712312359_Hour_6.csv invalid
# Data in filename Burghausen_GT_201701010000_201712312359_Hour_12.csv invalid
# Data in filename Buschhaus_201701010000_201712312359_Hour_13.csv invalid
# Data in filename Cuno_Heizkraftwerk_Herdecke_201701010000_201712312359_Hour_18.csv invalid
# Data in filename Datteln_201701010000_201712312359_Hour_20.csv invalid
# Data in filename Dormagen_201701010000_201712312359_Hour_22.csv invalid
# Data in filename Duisburg_Hamborn_201701010000_201712312359_Hour_23.csv invalid
# Data in filename Duisburg_Ruhrort_201701010000_201712312359_Hour_26.csv invalid
# Block name is 2+GT
# Data in filename Franken_1_201701010000_201712312359_Hour_33.csv invalid
# Data in filename Gaskraftwerk_Irsching_201701010000_201712312359_Hour_38.csv invalid
# Data in filename Gemeinschaftskraftwerk_Kiel_201701010000_201712312359_Hour_42.csv invalid
# Data in filename Heizkraftwerk_Altbach_Deizisau_201701010000_201712312359_Hour_55.csv invalid
# Data in filename Heizkraftwerk_Dresden-Nossener_Br_cke_201701010000_201712312359_Hour_57.csv invalid
# Data in filename Heizkraftwerk_Heilbronn_201701010000_201712312359_Hour_59.csv invalid
# Data in filename Heizkraftwerk_Leipzig-Nord_201701010000_201712312359_Hour_62.csv invalid
# Data in filename Heizkraftwerk_Merkenich_201701010000_201712312359_Hour_63.csv invalid
# Block name is 2DT
# Block name is 2GT
# Data in filename Heizkraftwerk_Niehl_201701010000_201712312359_Hour_67.csv invalid
# Data in filename Heizkraftwerk_R_merbr_cke_201701010000_201712312359_Hour_69.csv invalid
# Data in filename Heizkraftwerk_West_Wolfsburg_201701010000_201712312359_Hour_72.csv invalid
# Data in filename Heyden_201701010000_201712312359_Hour_74.csv invalid
# Data in filename Huntorf_201701010000_201712312359_Hour_78.csv invalid
# Data in filename Ibbenb_ren_201701010000_201712312359_Hour_79.csv invalid
# Data in filename IKS_PCK_Schwedt_201701010000_201712312359_Hour_80.csv invalid
# Data in filename Klingenberg_201701010000_201712312359_Hour_88.csv invalid
# Data in filename Knapsack_Gas_II_201701010000_201712312359_Hour_90.csv invalid
# Data in filename Knapsack_Gas_I_201701010000_201712312359_Hour_89.csv invalid
# Data in filename KNG_Kraftwerk_Rostock_201701010000_201712312359_Hour_91.csv invalid
# Data in filename Kraftwerk_BASF_Ludwigshafen_Mitte_201701010000_201712312359_Hour_95.csv invalid
# Block name is GT1
# Block name is GT2
# Data in filename Kraftwerk_Bexbach_201701010000_201712312359_Hour_97.csv invalid
# Data in filename Kraftwerk_Bremer_Hafen_201701010000_201712312359_Hour_98.csv invalid
# Data in filename Kraftwerk_Ensdorf_201701010000_201712312359_Hour_99.csv invalid
# Data in filename Kraftwerk_Farge_201701010000_201712312359_Hour_100.csv invalid
# Data in filename Kraftwerk_Hastedt_201701010000_201712312359_Hour_101.csv invalid
# Data in filename Kraftwerk_Herne_201701010000_201712312359_Hour_102.csv invalid
# Data in filename Kraftwerk_Ingolstadt_201701010000_201712312359_Hour_103.csv invalid
# Data in filename Kraftwerk_Mainz_201701010000_201712312359_Hour_107.csv invalid
# Data in filename Kraftwerk_Mittelsb_ren_201701010000_201712312359_Hour_108.csv invalid
# Data in filename Kraftwerk_Walheim_201701010000_201712312359_Hour_113.csv invalid
# Data in filename Kraftwerk_Walsum_201701010000_201712312359_Hour_114.csv invalid
# Data in filename Kraftwerk_Wilhelmshaven_201701010000_201712312359_Hour_117.csv invalid
# Data in filename KWH_Hannover_201701010000_201712312359_Hour_119.csv invalid
# Data in filename KWM_Mehrum_201701010000_201712312359_Hour_120.csv invalid
# Data in filename K_stenkraftwerk_K.I.E.L._201701010000_201712312359_Hour_118.csv invalid
# Data in filename Lichterfelde_201701010000_201712312359_Hour_122.csv invalid
# Data in filename M_nchen_Nord_2_201701010000_201712312359_Hour_132.csv invalid
# Block name is K-BoA1
# Data in filename Reuter_201701010000_201712312359_Hour_139.csv invalid
# Data in filename Rheinhafen-Dampfkraftwerk_201701010000_201712312359_Hour_141.csv invalid
# Data in filename Staudinger_201701010000_201712312359_Hour_151.csv invalid
# Data in filename Tiefstack_201701010000_201712312359_Hour_154.csv invalid
# Data in filename Trianel_Kohlekraftwerk_L_nen_201701010000_201712312359_Hour_157.csv invalid
# Data in filename Wedel_201701010000_201712312359_Hour_163.csv invalid
# Data in filename Weiher_201701010000_201712312359_Hour_166.csv invalid
# Block name is G-VGT
# Block name is H-VGT
# Data in filename Zolling_201701010000_201712312359_Hour_173.csv invalid
#               EIC-ID  Generation Year  Year                      Plant Name
# 0   11WD8BOXB1L---N8        3527767.0  2017                         Boxberg
# 1   11WD8BOXB1L---P4        3677257.0  2017                         Boxberg
# 2   11WD8BOXB1L---Q2        6814103.0  2017                         Boxberg
# 3   11WD8BOXB1L---R0        3414023.0  2017                         Boxberg
# 4   11WD8LIPD1L---R6        5634518.0  2017  Braunkohlekraftwerk_Lippendorf
# ..               ...              ...   ...                             ...
# 59  11WD7WEIS1B--H-G        5387540.0  2017                      Weisweiler
# 60  11WD7WEIS1B--F-M        2635057.0  2017                      Weisweiler
# 61  11WD7WEIS5B--E-Y        2159287.0  2017                      Weisweiler
# 62  11WD7WEST5S--C-P              0.0  2017                       Westfalen
# 63  11WD7WSFN1S--E-Z        3445223.0  2017                       Westfalen
#
# [64 rows x 4 columns]
